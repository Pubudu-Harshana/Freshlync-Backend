# %%
# %pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# VSCode.Cell language="python"
import matplotlib.pyplot as plt
import seaborn as sns

# Plotting Actual vs. Predicted values on testing data
plt.figure(figsize=(9, 6))

sns.scatterplot(x=y_test, y=y_pred_test, alpha=0.7, color='teal', edgecolor='black')

# Add optimal line
min_val = min(y_test.min(), y_pred_test.min())
max_val = max(y_test.max(), y_pred_test.max())
plt.plot([min_val, max_val], [min_val, max_val], color='red', linestyle='--', lw=2, label="Perfect Prediction Line")

plt.title('Freshlync Model: Actual vs Predicted Demand', fontsize=14)
plt.xlabel('Actual Quantity Sold', fontsize=12)
plt.ylabel('Predicted Quantity Sold', fontsize=12)
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 8
#       4
#       5 # Plotting Actual vs. Predicted values on testing data
#       6 plt.figure(figsize=(9, 6))
#       7
# ----> 8 sns.scatterplot(x=y_test, y=y_pred_test, alpha=0.7, color='teal', edgecolor='black')
#       9
#      10 # Add optimal line
#      11 min_val = min(y_test.min(), y_pred_test.min())
#
# NameError: name 'y_test' is not defined

# %%
# VSCode.Cell language="python"
import matplotlib.pyplot as plt
import numpy as np

# 1. Ensure the variables exist (Fallback check)
try:
    # Test if variables are already in memory
    _ = y_test, y_pred_test
except NameError:
    print("Variables not found in memory. Regenerating from pipeline...")
    # Re-run the critical steps natively
    X_processed = preprocessor.transform(X)
    X_train, X_test, y_train, y_test = train_test_split(X_processed, y, test_size=0.2, random_state=42)
    y_pred_test = model.predict(X_test)

# 2. Plotting Actual vs. Predicted values
plt.figure(figsize=(9, 6))
plt.scatter(y_test, y_pred_test, alpha=0.7, color='teal', edgecolor='black', zorder=2)

# Add optimal line
min_val = min(y_test.min(), y_pred_test.min())
max_val = max(y_test.max(), y_pred_test.max())
plt.plot([min_val, max_val], [min_val, max_val], color='red', linestyle='--', lw=2, label="Perfect Prediction Line", zorder=3)

plt.title('Freshlync Model: Actual vs Predicted Demand', fontsize=14)
plt.xlabel('Actual Quantity Sold', fontsize=12)
plt.ylabel('Predicted Quantity Sold', fontsize=12)
plt.legend()
plt.grid(True, alpha=0.3, zorder=1)
plt.tight_layout()

plt.show()
